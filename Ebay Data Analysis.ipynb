# %%
import pandas as pd

# %%
#Retrieve the dataset and take a look at the first 5 rows and last 5 rows
ebay_df = pd.read_csv('EbayPcLaptopDataUnclean.csv')
ebay_df
# Out:
#       Item Number   Brand Rating  Ratings Count               Processor  \
# 0     85264981001   CHUWI    NaN            NaN               Quad Core
# 1     85264981002    Dell    NaN            NaN  Intel Core i7 8th Gen.
# 2     85264981003    Dell    NaN            NaN     Intel Core i5-6300U
# 3     85264981004      HP    NaN            NaN         Intel Celeron N
# 4     85264981005    Dell    NaN            NaN  Intel Core i5 6th Gen.
# ...           ...     ...    ...            ...                     ...
# 6671  85264987616     NaN    NaN            NaN                     NaN
# 6672  85264987617     NaN    NaN            NaN                     NaN
# 6673  85264987618     NaN    NaN            NaN                     NaN
# 6674  85264987619  Lenovo    NaN            NaN                     NaN
# 6675  85264987620     NaN    NaN            NaN                     NaN
#
#         Screen Size Manufacturer Color  Color Ram Size  \
# 0             14 in                NaN   Gray     8 GB
# 1             14 in                NaN  Black      NaN
# 2             14 in                NaN  Black    16 GB
# 3           11.6 in                NaN  Black     4 GB
# 4     Minimum 12.5"                NaN    NaN     8 GB
# ...             ...                ...    ...      ...
# 6671            NaN                NaN    NaN      NaN
# 6672            NaN                NaN  Negro      NaN
# 6673            NaN                NaN    NaN      NaN
# 6674            NaN                NaN  Black      NaN
# 6675            NaN                NaN    NaN      NaN
#
#                                SSD Capacity  ...         Release Year  \
# 0     1 Used,  1 support Max 1TB M.2 Extend  ...                 2021
# 1                                       NaN  ...  Refurbished in 2023
# 2                                    500 GB  ...                 2019
# 3                                       NaN  ...                  NaN
# 4                                    256 GB  ...                 2015
# ...                                     ...  ...                  ...
# 6671                                    NaN  ...                  NaN
# 6672                                    NaN  ...                  NaN
# 6673                                    NaN  ...                  NaN
# 6674                                    NaN  ...                  NaN
# 6675                                    NaN  ...                  NaN
#
#      Maximum Resolution                Model               OS  \
# 0           2160 x 1440           CoreBook X  Windows 11 Home
# 1           1920 x 1080   Dell Latitude 7490   Windows 11 Pro
# 2           1920 x 1080  Dell Latitude E5470   Windows 10 Pro
# 3            1366 x 768  HP Chromebook 11 G6        Chrome OS
# 4            1366 x 768       Various Models       Windows 10
# ...                 ...                  ...              ...
# 6671                NaN                  NaN              NaN
# 6672                NaN                  NaN              NaN
# 6673                NaN                  NaN              NaN
# 6674                NaN                  NaN              NaN
# 6675                NaN                  NaN              NaN
#
#      Hard Drive Capacity Country Region Of Manufacture  \
# 0             512 GB SSD                         China
# 1                   2 TB                           NaN
# 2                 500 GB                         China
# 3                  16 GB                           NaN
# 4                 NO HDD                           NaN
# ...                  ...                           ...
# 6671                 NaN                           NaN
# 6672                 NaN                           NaN
# 6673                 NaN                           NaN
# 6674                 NaN                           NaN
# 6675                 NaN                           NaN
#
#                  Storage Type  \
# 0     SSD (Solid State Drive)
# 1     SSD (Solid State Drive)
# 2     SSD (Solid State Drive)
# 3                        eMMC
# 4     SSD (Solid State Drive)
# ...                       ...
# 6671                      NaN
# 6672                      NaN
# 6673                      NaN
# 6674                      NaN
# 6675                      NaN
#
#                                                Features  \
# 0     Backlit Keyboard,  Built-in Microphone,  Built...
# 1     Backlit Keyboard, Bluetooth, Built-in Micropho...
# 2     10/100 LAN Card, Backlit Keyboard, Bluetooth, ...
# 3     Bluetooth, Built-in Microphone, Built-in Webca...
# 4     10/100 LAN Card, Built-in Microphone, Built-in...
# ...                                                 ...
# 6671                                                NaN
# 6672                                                NaN
# 6673                                                NaN
# 6674                                                NaN
# 6675                                                NaN
#
#                                               Condition  \
# 0     New: A brand-new, unused, unopened, undamaged ...
# 1     Very Good - RefurbishedThe item shows minimal ...
# 2     UsedAn item that has been used previously. The...
# 3     Good - RefurbishedThe item shows moderate wear...
# 4     Good - RefurbishedThe item shows moderate wear...
# ...                                                 ...
# 6671  New: A brand-new, unused, unopened, undamaged ...
# 6672  Seller refurbished: The item has been restored...
# 6673  New: A brand-new, unused, unopened, undamaged ...
# 6674                                                NaN
# 6675  New: A brand-new, unused, unopened, undamaged ...
#
#                                             Seller Note
# 0                                                   NaN
# 1     “AAA PCs is a Microsoft Authorized Refurbisher...
# 2     “Well kept, fully functional, includes battery...
# 3     “1-Year Allstate warranty. The original HP cha...
# 4     “Laptops is tested & fully working with some s...
# ...                                                 ...
# 6671                                                NaN
# 6672                                                NaN
# 6673                                                NaN
# 6674                                                NaN
# 6675                                                NaN
#
# [6676 rows x 23 columns]

# %% [markdown]
# The First thing I am going to do to analyze this data is to find the percentage of each column is missing values. From first glance, it seems like there are many missing values in this dataset.

# %%
#Done by using the .isna() pandas function
ebay_df.isna().sum() / len(ebay_df) * 100
# Out:
# Item Number                       0.000000
# Brand                            38.615938
# Rating                           95.641102
# Ratings Count                    95.641102
# Processor                        41.446974
# Screen Size                      40.638107
# Manufacturer Color               97.153984
# Color                            67.121031
# Ram Size                         67.450569
# SSD Capacity                     57.399641
# GPU                              53.235470
# Processor Speed                  59.152187
# Type                             49.835231
# Release Year                     87.807070
# Maximum Resolution               62.088077
# Model                            51.842421
# OS                               53.520072
# Hard Drive Capacity              64.439784
# Country Region Of Manufacture    96.929299
# Storage Type                     63.406231
# Features                         61.698622
# Condition                         9.376872
# Seller Note                      77.741162
# dtype: float64

# %% [markdown]
# As we can see from this snapshot, there are quite a few columns with a missing value rate of above an 80%. Next I am going to determing which columns I can use to fill in some of these blanks.

# %% [markdown]
# I am going to drop the Seller Note and Features Column since they are not useful for analysis.

# %% [markdown]
# I am going to drop ratings count and ratings because they are missing 95% of their data. Using these datapoints will delete almost all of the rows of the dataset.

# %%
ebay_df = ebay_df.drop(columns=['Seller Note', 'Features', 'Rating', 'Ratings Count'])
ebay_df.head()
# Out:
#    Item Number  Brand               Processor    Screen Size  \
# 0  85264981001  CHUWI               Quad Core          14 in
# 1  85264981002   Dell  Intel Core i7 8th Gen.          14 in
# 2  85264981003   Dell     Intel Core i5-6300U          14 in
# 3  85264981004     HP         Intel Celeron N        11.6 in
# 4  85264981005   Dell  Intel Core i5 6th Gen.  Minimum 12.5"
#
#   Manufacturer Color  Color Ram Size                           SSD Capacity  \
# 0                NaN   Gray     8 GB  1 Used,  1 support Max 1TB M.2 Extend
# 1                NaN  Black      NaN                                    NaN
# 2                NaN  Black    16 GB                                 500 GB
# 3                NaN  Black     4 GB                                    NaN
# 4                NaN    NaN     8 GB                                 256 GB
#
#                             GPU                     Processor Speed  \
# 0  Intel Iris Plus Graphics 655                  Max up to 3.80 GHz
# 1        Intel UHD Graphics 620  4.20 GHz (1.90 GHz Base Frequency)
# 2             Intel HD Graphics                            2.40 GHz
# 3         Intel HD Graphics 500                            2.40 GHz
# 4                    Integrated                    Minimum 1.40 GHz
#
#               Type         Release Year Maximum Resolution  \
# 0  Notebook/Laptop                 2021        2160 x 1440
# 1  Notebook/Laptop  Refurbished in 2023        1920 x 1080
# 2  Notebook/Laptop                 2019        1920 x 1080
# 3  Notebook/Laptop                  NaN         1366 x 768
# 4  Notebook/Laptop                 2015         1366 x 768
#
#                  Model               OS Hard Drive Capacity  \
# 0           CoreBook X  Windows 11 Home          512 GB SSD
# 1   Dell Latitude 7490   Windows 11 Pro                2 TB
# 2  Dell Latitude E5470   Windows 10 Pro              500 GB
# 3  HP Chromebook 11 G6        Chrome OS               16 GB
# 4       Various Models       Windows 10              NO HDD
#
#   Country Region Of Manufacture             Storage Type  \
# 0                         China  SSD (Solid State Drive)
# 1                           NaN  SSD (Solid State Drive)
# 2                         China  SSD (Solid State Drive)
# 3                           NaN                     eMMC
# 4                           NaN  SSD (Solid State Drive)
#
#                                            Condition
# 0  New: A brand-new, unused, unopened, undamaged ...
# 1  Very Good - RefurbishedThe item shows minimal ...
# 2  UsedAn item that has been used previously. The...
# 3  Good - RefurbishedThe item shows moderate wear...
# 4  Good - RefurbishedThe item shows moderate wear...

# %% [markdown]
# I am first going to focus on filling in missing values for the country region of manufacture column. I can do this because I know the brand of the laptops. I can find a dictionary online of brands mapped to country region and use this to fill in the missing country.

# %% [markdown]
# I first need to clean the brand column.

# %%
ebay_df['Brand'].unique()
# Out:
# array(['CHUWI', 'Dell', 'HP', 'Acer', 'Lenovo', 'Samsung', 'Chuwi', nan,
#        'Microsoft', 'LG', 'Toshiba', 'SGIN', 'Panasonic', 'ASUS', 'Olpc',
#        'Mouse Computer', 'AUUSDA', 'Apple', 'Fujitsu Siemens', 'Fujitsu',
#        'AUO', 'KODAK', 'LCD Replacement', 'Packard Bell', 'Intel',
#        'Olidata', 'IVO', 'JVC', 'Unbranded', 'Simpletek',
#        'ChiMei INNOLUX', 'INNOLUX', 'Getac', 'DELL', 'Google',
#        'HW13WX001', 'Compaq', 'Casio', 'ChiMei', 'HannStar', 'Delta',
#        'Hyundai', '?', 'FEC', 'AU Optronics', 'Chunghwa', 'CLAA156WA13A',
#        'Alienware', 'VAIO', 'Sony', 'Does not apply', 'C600',
#        'CLAA156WA11A', 'Chimei INNOLUX', 'VECTOR', 'LiteON', 'CHUNGWA',
#        'Kodak', 'Uniwill', 'Asem', 'InnoLux',
#        'HP DELL LENOVO SELECT FROM ABOVE', 'Zebra', 'Geo', 'MSI',
#        'Gateway', 'dell', 'Fujitsu PC Corp.', 'Asus', 'HiDes', 'GPD',
#        'XPLORE', 'Craig', 'PANASONIC', 'Huawei', 'Metabox', 'Different',
#        'Orbitkey', 'Kano', 'IBM', 'See Title/Description', 'Jumper',
#        'Media Wave', 'Durabook', 'Not Applicable', 'GIGABYTE',
#        'DELL/HP/LENOVO/Fujitsu/Toshiba', 'LENOVO', 'Razer', 'Lenova',
#        'GETAC', 'Fusion5', 'Dell Inc.', 'AMIAMO', 'Packard bell',
#        'Lenovo T530', 'Dell 16gb', 'ProBook', 'AIRBAR', 'Zzetze',
#        'Motion Computing', 'GoldBook', 'Dell Inspiron', 'Insignia',
#        'Universal', 'Dell Latitude', 'Unbranded/Generic', 'CLEVO',
#        'Major Brand', 'ACER', 'CLAA116WA03A', 'Shed Number 2',
#        'www.TAG1000Diver.com', 'nevada', 'Olympus', 'Chingwa',
#        'Apple / LG', 'HannnStar', 'Fuji', 'Sony VAIO', 'Delta / DELL',
#        'Lenovo T440', 'Dell Latitude 7275', 'Mixt', 'GERICOM',
#        'Top Performance', 'MEDION', 'CHUNGHWA', 'Vulcan Electronics',
#        'Frontier', 'Dell/HP/Lenovo/Stone', 'SCSI', 'xnote',
#        'Acer / IOmega', 'Bormann'], dtype=object)

# %%
#Make each of the brands title case to deal with capitalization mistakes
ebay_df['Brand'] = ebay_df['Brand'].str.title()
ebay_df['Brand'].unique()
# Out:
# array(['Chuwi', 'Dell', 'Hp', 'Acer', 'Lenovo', 'Samsung', nan,
#        'Microsoft', 'Lg', 'Toshiba', 'Sgin', 'Panasonic', 'Asus', 'Olpc',
#        'Mouse Computer', 'Auusda', 'Apple', 'Fujitsu Siemens', 'Fujitsu',
#        'Auo', 'Kodak', 'Lcd Replacement', 'Packard Bell', 'Intel',
#        'Olidata', 'Ivo', 'Jvc', 'Unbranded', 'Simpletek',
#        'Chimei Innolux', 'Innolux', 'Getac', 'Google', 'Hw13Wx001',
#        'Compaq', 'Casio', 'Chimei', 'Hannstar', 'Delta', 'Hyundai', '?',
#        'Fec', 'Au Optronics', 'Chunghwa', 'Claa156Wa13A', 'Alienware',
#        'Vaio', 'Sony', 'Does Not Apply', 'C600', 'Claa156Wa11A', 'Vector',
#        'Liteon', 'Chungwa', 'Uniwill', 'Asem',
#        'Hp Dell Lenovo Select From Above', 'Zebra', 'Geo', 'Msi',
#        'Gateway', 'Fujitsu Pc Corp.', 'Hides', 'Gpd', 'Xplore', 'Craig',
#        'Huawei', 'Metabox', 'Different', 'Orbitkey', 'Kano', 'Ibm',
#        'See Title/Description', 'Jumper', 'Media Wave', 'Durabook',
#        'Not Applicable', 'Gigabyte', 'Dell/Hp/Lenovo/Fujitsu/Toshiba',
#        'Razer', 'Lenova', 'Fusion5', 'Dell Inc.', 'Amiamo', 'Lenovo T530',
#        'Dell 16Gb', 'Probook', 'Airbar', 'Zzetze', 'Motion Computing',
#        'Goldbook', 'Dell Inspiron', 'Insignia', 'Universal',
#        'Dell Latitude', 'Unbranded/Generic', 'Clevo', 'Major Brand',
#        'Claa116Wa03A', 'Shed Number 2', 'Www.Tag1000Diver.Com', 'Nevada',
#        'Olympus', 'Chingwa', 'Apple / Lg', 'Hannnstar', 'Fuji',
#        'Sony Vaio', 'Delta / Dell', 'Lenovo T440', 'Dell Latitude 7275',
#        'Mixt', 'Gericom', 'Top Performance', 'Medion',
#        'Vulcan Electronics', 'Frontier', 'Dell/Hp/Lenovo/Stone', 'Scsi',
#        'Xnote', 'Acer / Iomega', 'Bormann'], dtype=object)

# %%
#Find the brand titles that I know are not right from looking at the unique values in the Brand Column
bad_brands = ['Hw13Wx001', 'Claa156Wa13A', '?', 'Does Not Apply', 'C600', 'Hp Dell Lenovo Select From Above', 
              'See Title/Description', 'Not Applicable', 'Dell/Hp/Lenovo/Fujitsu/Toshiba', 'Zzetze', 'Unbranded/Generic',
              'Major Brand', 'Claa116Wa03A', 'Shed Number 2', 'Www.Tag1000Diver.Com', 'Apple / Lg', 'Delta / Dell', 
              'Dell/Hp/Lenovo/Stone', 'Acer / Iomega', 'Lcd Replacement', 'Chimei Innolux', 'Claa156Wa11A', 'Unbranded',
              'Different', 'Simpletek', 'Vector', 'Hides', 'Media Wave', 'Probook', 'Airbar', 'Goldbook', 'Nevada', 'Mixt',
              'Top Performance', 'Scsi', 'Bormann']

#Systematically remove these "bad_brands"
for brand in bad_brands:
    ebay_df = ebay_df[ebay_df['Brand'] != brand]

# %%
ebay_df['Brand'].unique()
# Out:
# array(['Chuwi', 'Dell', 'Hp', 'Acer', 'Lenovo', 'Samsung', nan,
#        'Microsoft', 'Lg', 'Toshiba', 'Sgin', 'Panasonic', 'Asus', 'Olpc',
#        'Mouse Computer', 'Auusda', 'Apple', 'Fujitsu Siemens', 'Fujitsu',
#        'Auo', 'Kodak', 'Packard Bell', 'Intel', 'Olidata', 'Ivo', 'Jvc',
#        'Innolux', 'Getac', 'Google', 'Compaq', 'Casio', 'Chimei',
#        'Hannstar', 'Delta', 'Hyundai', 'Fec', 'Au Optronics', 'Chunghwa',
#        'Alienware', 'Vaio', 'Sony', 'Liteon', 'Chungwa', 'Uniwill',
#        'Asem', 'Zebra', 'Geo', 'Msi', 'Gateway', 'Fujitsu Pc Corp.',
#        'Gpd', 'Xplore', 'Craig', 'Huawei', 'Metabox', 'Orbitkey', 'Kano',
#        'Ibm', 'Jumper', 'Durabook', 'Gigabyte', 'Razer', 'Lenova',
#        'Fusion5', 'Dell Inc.', 'Amiamo', 'Lenovo T530', 'Dell 16Gb',
#        'Motion Computing', 'Dell Inspiron', 'Insignia', 'Universal',
#        'Dell Latitude', 'Clevo', 'Olympus', 'Chingwa', 'Hannnstar',
#        'Fuji', 'Sony Vaio', 'Lenovo T440', 'Dell Latitude 7275',
#        'Gericom', 'Medion', 'Vulcan Electronics', 'Frontier', 'Xnote'],
#       dtype=object)

# %% [markdown]
# The Brands Column is looking better. However, there are still brand variants that are in the column that can be transformed.

# %%
ebay_df['Brand'].replace(to_replace=['Dell Inc.', 'Dell 16Gb', 'Dell Inspiron', 'Dell Latitude',
                                                        'Dell Latitude 7275'], value='Dell', inplace=True)
ebay_df['Brand'].replace(to_replace=['Lenova', 'Lenovo T530', 'Lenovo T440'], value='Lenovo', inplace=True)
ebay_df['Brand'].replace(to_replace=['Sony Vaio'], value='Sony', inplace=True)
ebay_df['Brand'].replace(to_replace=['Chingwa'], value='Chunghwa', inplace=True)
# Out:
# C:\Users\trush\AppData\Local\Temp\ipykernel_33596\31614139.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ebay_df['Brand'].replace(to_replace=['Dell Inc.', 'Dell 16Gb', 'Dell Inspiron', 'Dell Latitude',

# %% [markdown]
# After taking away all of the variants of brand, we can now say that the Brand column is cleaned.

# %%
ebay_df['Brand'].unique()
# Out:
# array(['Chuwi', 'Dell', 'Hp', 'Acer', 'Lenovo', 'Samsung', nan,
#        'Microsoft', 'Lg', 'Toshiba', 'Sgin', 'Panasonic', 'Asus', 'Olpc',
#        'Mouse Computer', 'Auusda', 'Apple', 'Fujitsu Siemens', 'Fujitsu',
#        'Auo', 'Kodak', 'Packard Bell', 'Intel', 'Olidata', 'Ivo', 'Jvc',
#        'Innolux', 'Getac', 'Google', 'Compaq', 'Casio', 'Chimei',
#        'Hannstar', 'Delta', 'Hyundai', 'Fec', 'Au Optronics', 'Chunghwa',
#        'Alienware', 'Vaio', 'Sony', 'Liteon', 'Chungwa', 'Uniwill',
#        'Asem', 'Zebra', 'Geo', 'Msi', 'Gateway', 'Fujitsu Pc Corp.',
#        'Gpd', 'Xplore', 'Craig', 'Huawei', 'Metabox', 'Orbitkey', 'Kano',
#        'Ibm', 'Jumper', 'Durabook', 'Gigabyte', 'Razer', 'Fusion5',
#        'Amiamo', 'Motion Computing', 'Insignia', 'Universal', 'Clevo',
#        'Olympus', 'Hannnstar', 'Fuji', 'Gericom', 'Medion',
#        'Vulcan Electronics', 'Frontier', 'Xnote'], dtype=object)

# %% [markdown]
# To finish the Brand column we will remove the entries with NaN as brand

# %%
ebay_df = ebay_df[ebay_df['Brand'].notna()]

ebay_df.isna().sum() / len(ebay_df) * 100
# Out:
# Item Number                       0.000000
# Brand                             0.000000
# Processor                         4.625885
# Screen Size                       3.260870
# Manufacturer Color               95.197169
# Color                            52.350859
# Ram Size                         45.298281
# SSD Capacity                     29.196158
# GPU                              43.629929
# Processor Speed                  32.330637
# Type                             24.089990
# Release Year                     79.550051
# Maximum Resolution               37.259858
# Model                            20.273003
# OS                               23.053589
# Hard Drive Capacity              41.102123
# Country Region Of Manufacture    94.843276
# Storage Type                     39.509606
# Condition                        12.007078
# dtype: float64

# %% [markdown]
# Now looking at this snapshot, the columns have gotten better with missing values! I have decided to drop the Manufacturer Color column since 95% of it is missing, and we have a color column that would achieve the same purpose in an analysis.

# %%
ebay_df = ebay_df.drop(columns=['Manufacturer Color'])
ebay_df
# Out:
#       Item Number   Brand                     Processor     Screen Size  \
# 0     85264981001   Chuwi                     Quad Core           14 in
# 1     85264981002    Dell        Intel Core i7 8th Gen.           14 in
# 2     85264981003    Dell           Intel Core i5-6300U           14 in
# 3     85264981004      Hp               Intel Celeron N         11.6 in
# 4     85264981005    Dell        Intel Core i5 6th Gen.   Minimum 12.5"
# ...           ...     ...                           ...             ...
# 6666  85264987611    Dell  Intel Core i5 4th generation             14"
# 6668  85264987613      Hp                Does not apply  Does not apply
# 6669  85264987614     Auo                Does not apply  Does not apply
# 6670  85264987615   Apple                Does not apply  Does not apply
# 6674  85264987619  Lenovo                           NaN             NaN
#
#       Color Ram Size                           SSD Capacity  \
# 0      Gray     8 GB  1 Used,  1 support Max 1TB M.2 Extend
# 1     Black      NaN                                    NaN
# 2     Black    16 GB                                 500 GB
# 3     Black     4 GB                                    NaN
# 4       NaN     8 GB                                 256 GB
# ...     ...      ...                                    ...
# 6666    NaN      NaN                                  960GB
# 6668    NaN      NaN                                    NaN
# 6669    NaN      NaN                                    NaN
# 6670    NaN      NaN                                    NaN
# 6674  Black      NaN                                    NaN
#
#                                GPU                     Processor Speed  \
# 0     Intel Iris Plus Graphics 655                  Max up to 3.80 GHz
# 1           Intel UHD Graphics 620  4.20 GHz (1.90 GHz Base Frequency)
# 2                Intel HD Graphics                            2.40 GHz
# 3            Intel HD Graphics 500                            2.40 GHz
# 4                       Integrated                    Minimum 1.40 GHz
# ...                            ...                                 ...
# 6666         Nvidia GeForce GT720M                                 NaN
# 6668                           NaN                                 NaN
# 6669                           NaN                                 NaN
# 6670                           NaN                                 NaN
# 6674                           NaN                                 NaN
#
#                  Type         Release Year Maximum Resolution  \
# 0     Notebook/Laptop                 2021        2160 x 1440
# 1     Notebook/Laptop  Refurbished in 2023        1920 x 1080
# 2     Notebook/Laptop                 2019        1920 x 1080
# 3     Notebook/Laptop                  NaN         1366 x 768
# 4     Notebook/Laptop                 2015         1366 x 768
# ...               ...                  ...                ...
# 6666           Laptop                  NaN                 HD
# 6668              NaN                  NaN                NaN
# 6669              NaN                  NaN                NaN
# 6670              NaN                  NaN                NaN
# 6674  Notebook/Laptop                  NaN                NaN
#
#                     Model               OS Hard Drive Capacity  \
# 0              CoreBook X  Windows 11 Home          512 GB SSD
# 1      Dell Latitude 7490   Windows 11 Pro                2 TB
# 2     Dell Latitude E5470   Windows 10 Pro              500 GB
# 3     HP Chromebook 11 G6        Chrome OS               16 GB
# 4          Various Models       Windows 10              NO HDD
# ...                   ...              ...                 ...
# 6666                E5440   Windows 11 Pro                  NO
# 6668                  NaN              NaN                 NaN
# 6669                  NaN              NaN                 NaN
# 6670                  NaN              NaN                 NaN
# 6674                  NaN              NaN                 NaN
#
#      Country Region Of Manufacture             Storage Type  \
# 0                            China  SSD (Solid State Drive)
# 1                              NaN  SSD (Solid State Drive)
# 2                            China  SSD (Solid State Drive)
# 3                              NaN                     eMMC
# 4                              NaN  SSD (Solid State Drive)
# ...                            ...                      ...
# 6666                           NaN                      NaN
# 6668                           NaN                      NaN
# 6669                           NaN                      NaN
# 6670                           NaN                      NaN
# 6674                           NaN                      NaN
#
#                                               Condition
# 0     New: A brand-new, unused, unopened, undamaged ...
# 1     Very Good - RefurbishedThe item shows minimal ...
# 2     UsedAn item that has been used previously. The...
# 3     Good - RefurbishedThe item shows moderate wear...
# 4     Good - RefurbishedThe item shows moderate wear...
# ...                                                 ...
# 6666  Used: An item that has been used previously. T...
# 6668  New: A brand-new, unused, unopened, undamaged ...
# 6669  New: A brand-new, unused, unopened, undamaged ...
# 6670  New: A brand-new, unused, unopened, undamaged ...
# 6674                                                NaN
#
# [3956 rows x 18 columns]

# %% [markdown]
# We can now use this completed Brand column to fill in more of the Country Region of Manufacture column by creaing a reference table using ChatGPT!

# %%
manufacturers = {
    'Chuwi': 'China', 'Dell': 'USA', 'Hp': 'USA',
    'Acer': 'Taiwan',
    'Lenovo': 'China',
    'Samsung': 'South Korea',
    'Microsoft': 'USA',
    'Lg': 'South Korea',
    'Toshiba': 'Japan',
    'Sgin': 'China',
    'Panasonic': 'Japan',
    'Asus': 'Taiwan',
    'Olpc': 'USA',
    'Mouse Computer': 'Japan',
    'Auusda': 'China',
    'Apple': 'USA',
    'Fujitsu Siemens': 'Germany',
    'Fujitsu': 'Japan',
    'Auo': 'Taiwan',
    'Kodak': 'USA',
    'Packard Bell': 'Netherlands',
    'Intel': 'USA',
    'Olidata': 'Italy',
    'Ivo': 'Taiwan',
    'Jvc': 'Japan',
    'Innolux': 'Taiwan',
    'Getac': 'Taiwan',
    'Google': 'USA',
    'Compaq': 'USA',
    'Casio': 'Japan',
    'Chimei': 'Taiwan',
    'Hannstar': 'Taiwan',
    'Delta': 'Taiwan',
    'Hyundai': 'South Korea',
    'Fec': 'Taiwan',
    'Au Optronics': 'Taiwan',
    'Chunghwa': 'Taiwan',
    'Alienware': 'USA',
    'Vaio': 'Japan',
    'Sony': 'Japan',
    'Liteon': 'Taiwan',
    'Chungwa': 'Taiwan',
    'Uniwill': 'Taiwan',
    'Asem': 'Italy',
    'Zebra': 'USA',
    'Geo': 'UK',
    'Msi': 'Taiwan',
    'Gateway': 'USA',
    'Fujitsu Pc Corp.': 'Japan',
    'Gpd': 'China',
    'Xplore': 'USA',
    'Craig': 'USA',
    'Huawei': 'China',
    'Metabox': 'Australia',
    'Orbitkey': 'Australia',
    'Kano': 'UK',
    'Ibm': 'USA',
    'Jumper': 'China',
    'Durabook': 'Taiwan',
    'Gigabyte': 'Taiwan',
    'Razer': 'USA',
    'Fusion5': 'UK',
    'Amiamo': 'USA',
    'Motion Computing': 'USA',
    'Insignia': 'USA',
    'Universal': 'USA',
    'Clevo': 'Taiwan',
    'Olympus': 'Japan',
    'Hannnstar': 'Taiwan',
    'Fuji': 'Japan',
    'Gericom': 'Austria',
    'Medion': 'Germany',
    'Vulcan Electronics': 'USA',
    'Frontier': 'Japan',
    'Xnote': 'South Korea'
}

# %% [markdown]
# Now that we have the reference table, we can make a list that corresponds with the brand, drop the old Country Region Of Manufacture, and assign the new list as the new Country Region Of Manufacture column.

# %%
countries_per_brand = []
for brand in ebay_df['Brand']:
    countries_per_brand.append(manufacturers[brand])
len(countries_per_brand)

ebay_df = ebay_df.drop(columns=['Country Region Of Manufacture'])

ebay_df['Country Region Of Manufacture'] = countries_per_brand

# %%
ebay_df = ebay_df[ebay_df['Brand'].notna()]

ebay_df.isna().sum() / len(ebay_df) * 100
# Out:
# Item Number                       0.000000
# Brand                             0.000000
# Processor                         4.625885
# Screen Size                       3.260870
# Color                            52.350859
# Ram Size                         45.298281
# SSD Capacity                     29.196158
# GPU                              43.629929
# Processor Speed                  32.330637
# Type                             24.089990
# Release Year                     79.550051
# Maximum Resolution               37.259858
# Model                            20.273003
# OS                               23.053589
# Hard Drive Capacity              41.102123
# Storage Type                     39.509606
# Condition                        12.007078
# Country Region Of Manufacture     0.000000
# dtype: float64

# %%
ebay_df['Country Region Of Manufacture'].unique()
# Out:
# array(['China', 'USA', 'Taiwan', 'South Korea', 'Japan', 'Germany',
#        'Netherlands', 'Italy', 'UK', 'Australia', 'Austria'], dtype=object)

# %%
ebay_df.head()
# Out:
#    Item Number  Brand               Processor    Screen Size  Color Ram Size  \
# 0  85264981001  Chuwi               Quad Core          14 in   Gray     8 GB
# 1  85264981002   Dell  Intel Core i7 8th Gen.          14 in  Black      NaN
# 2  85264981003   Dell     Intel Core i5-6300U          14 in  Black    16 GB
# 3  85264981004     Hp         Intel Celeron N        11.6 in  Black     4 GB
# 4  85264981005   Dell  Intel Core i5 6th Gen.  Minimum 12.5"    NaN     8 GB
#
#                             SSD Capacity                           GPU  \
# 0  1 Used,  1 support Max 1TB M.2 Extend  Intel Iris Plus Graphics 655
# 1                                    NaN        Intel UHD Graphics 620
# 2                                 500 GB             Intel HD Graphics
# 3                                    NaN         Intel HD Graphics 500
# 4                                 256 GB                    Integrated
#
#                       Processor Speed             Type         Release Year  \
# 0                  Max up to 3.80 GHz  Notebook/Laptop                 2021
# 1  4.20 GHz (1.90 GHz Base Frequency)  Notebook/Laptop  Refurbished in 2023
# 2                            2.40 GHz  Notebook/Laptop                 2019
# 3                            2.40 GHz  Notebook/Laptop                  NaN
# 4                    Minimum 1.40 GHz  Notebook/Laptop                 2015
#
#   Maximum Resolution                Model               OS  \
# 0        2160 x 1440           CoreBook X  Windows 11 Home
# 1        1920 x 1080   Dell Latitude 7490   Windows 11 Pro
# 2        1920 x 1080  Dell Latitude E5470   Windows 10 Pro
# 3         1366 x 768  HP Chromebook 11 G6        Chrome OS
# 4         1366 x 768       Various Models       Windows 10
#
#   Hard Drive Capacity             Storage Type  \
# 0          512 GB SSD  SSD (Solid State Drive)
# 1                2 TB  SSD (Solid State Drive)
# 2              500 GB  SSD (Solid State Drive)
# 3               16 GB                     eMMC
# 4              NO HDD  SSD (Solid State Drive)
#
#                                            Condition  \
# 0  New: A brand-new, unused, unopened, undamaged ...
# 1  Very Good - RefurbishedThe item shows minimal ...
# 2  UsedAn item that has been used previously. The...
# 3  Good - RefurbishedThe item shows moderate wear...
# 4  Good - RefurbishedThe item shows moderate wear...
#
#   Country Region Of Manufacture
# 0                         China
# 1                           USA
# 2                           USA
# 3                           USA
# 4                           USA

# %% [markdown]
# The next thing I am going to do is make the formatting consistent for the numerical categories. My plan is to convert all of these categories to floats, and add the units to the column headers. This will make analysis on this dataset much easier.

# %% [markdown]
# The first column I am going to work on is screen size

# %%
ebay_df.dtypes
# Out:
# Item Number                       int64
# Brand                            object
# Processor                        object
# Screen Size                      object
# Color                            object
# Ram Size                         object
# SSD Capacity                     object
# GPU                              object
# Processor Speed                  object
# Type                             object
# Release Year                     object
# Maximum Resolution               object
# Model                            object
# OS                               object
# Hard Drive Capacity              object
# Storage Type                     object
# Condition                        object
# Country Region Of Manufacture    object
# dtype: object

# %%
ebay_df['Screen Size'].unique()
# Out:
# array(['14 in', '11.6 in', 'Minimum 12.5"', '11.6 inin', '13.3 in',
#        '14.1 in', '2 in', '15.6 in', '11 in', '16 in', '12.5 in', '13 in',
#        '12 in', '15.6" 1080P FHD', '13.5 in', '17.3 in', '18.4 in',
#        '12.3 in', '10.1 in', '14.1in.', '14"', '7.2 in', 'Does not apply',
#        nan, '15,6"', '12, 5"', '13, 3"', '15.4 in', '13,3"',
#        '14,1 Zoll (35,8 cm)', '12,5"', '14" 35, 5cm', '15, 6"', '14, 1"',
#        '15.6 inches', '13"', '15"', '17 in', '15 in', '9.7 In', '8.1 in',
#        '11.6"', '10.95 in', '14.1"', '7 in', '17.3in', '14,1"', '10, 8"',
#        '11, 6"', '10,8"', '15, 4"', '18 in', '14', '15.6&quot;',
#        '16.1 in', '14 inin', '14" Touchscreen', '13, 5"', '11,6"',
#        '14" touchscreen', '10.5 in', '12.5', '15,4"', '15.6"', '10.8 in',
#        '12.1 in', '12.2 in', '16.0 in', '12.5in', '14" HD Matte Display',
#        '14 inch', '13.4 in', '15&quot;', '12 in In.3in.', '14.0"',
#        '13.3"', '10.4 in', '17.3',
#        '12" LED Touchscreen (Outdoor Viewable)', '13" 14\'', '10 in',
#        'GLASSES SCREEN', '14 In', '15.6', '14 in.', '15.6" Touch Screen',
#        '15.5 in', '13in', '15.6 In', '14.5 in', '12.5" FHD (1920x1080)',
#        '12.5"', '11.5 in', "15.6'",
#        '11.6 in in in in in in in in in Inin.', '13.3in', '15.6in.',
#        '14 Inch', '10.3 in', '10.1in', '10.2 in', '14&quot;', '14in.',
#        '13.7 in', '15 in In.4in.', '11.6 inin.', 'DOES NOT APPLY',
#        '17.3"', '13.2', '13.9 in', '10.8 "', '13.3in.', '9.5 in', '12.3"',
#        '13.1 in', '13.3', '15.6 In.', '12.5-15.6', '15.5"', '14.2 in',
#        '12.4 in', '13,5"', '12,1', '8.1', '15.6in', '?', 'Laptop, in',
#        '10.1" LED Touchscreen (Outdoor Viewable)', '15.6 in FHD',
#        '12.5" Full HD Touch', '11.6 in in Inin.', '9.7 in', '10.5',
#        '15.4"', '17,3"', '12.5in.', '13.3" QHD+ 3K Touch Screen', 'na',
#        '15.6 inin', '13.3 In', '13.3" touchscreen', '14in'], dtype=object)

# %%
#Since these values are all in inches, I am going to remove inches off of all of the strings in the column
#First I am going to make everything lowercase to make it easier on myself

#We can remove the null values from this column since there is only 3% of them
ebay_df = ebay_df[ebay_df['Screen Size'].notna()]

ebay_df['Screen Size'] = ebay_df['Screen Size'].str.lower()
ebay_df['Screen Size'] = ebay_df['Screen Size'].str.replace('in', '')
ebay_df['Screen Size'] = ebay_df['Screen Size'].str.replace(',', '.')
ebay_df['Screen Size'] = ebay_df['Screen Size'].str.strip()

new_sizes = []
for size in ebay_df['Screen Size']:
    size = ''.join([char for char in size if char.isdigit() or char == '.'])
    new_sizes.append(size)

#Create a new pandas series for the numerical sizes
numerical_sizes = pd.Series(new_sizes)
ebay_df['Numerical Sizes'] = numerical_sizes

#ebay_df['Screen Size'].unique()

# %%
ebay_df = ebay_df[ebay_df['Numerical Sizes'] != '']
ebay_df = ebay_df[ebay_df['Numerical Sizes'] != '.']

ebay_df['Numerical Sizes'] = ebay_df['Numerical Sizes'].str[:4]

ebay_df = ebay_df[ebay_df['Numerical Sizes'].notna()]

ebay_df['Numerical Sizes'] = ebay_df['Numerical Sizes'].replace('1314', '13')

ebay_df['Numerical Sizes'].unique()
# Out:
# array(['14', '11.6', '12.5', '13.3', '14.1', '2', '15.6', '11', '16',
#        '12', '13.5', '17.3', '18.4', '12.3', '10.1', '13', '7.2', '15',
#        '8.1', '17', '10.8', '18', '16.1', '15.4', '12.1', '12.2', '10.5',
#        '7', '13.4', '10', '14.0', '14.5', '15.5', '13.9', '10.2', '13.1',
#        '14.', '14.2', '12.4', '11.5', '9.7', '16.0', '13.2', '10.3'],
#       dtype=object)

# %%
ebay_df['Numerical Sizes'] = ebay_df['Numerical Sizes'].astype(float)
ebay_df = ebay_df.drop(columns=['Screen Size'])
ebay_df.rename(columns={'Numerical Sizes': 'Screen Size (in)'}, inplace=True)
screen_sizes = ebay_df.pop('Screen Size (in)')
ebay_df.insert(3, 'Screen Size (in)', screen_sizes)
ebay_df.head()
# Out:
#    Item Number  Brand               Processor  Screen Size (in)  Color  \
# 0  85264981001  Chuwi               Quad Core              14.0   Gray
# 1  85264981002   Dell  Intel Core i7 8th Gen.              14.0  Black
# 2  85264981003   Dell     Intel Core i5-6300U              14.0  Black
# 3  85264981004     Hp         Intel Celeron N              11.6  Black
# 4  85264981005   Dell  Intel Core i5 6th Gen.              12.5    NaN
#
#   Ram Size                           SSD Capacity  \
# 0     8 GB  1 Used,  1 support Max 1TB M.2 Extend
# 1      NaN                                    NaN
# 2    16 GB                                 500 GB
# 3     4 GB                                    NaN
# 4     8 GB                                 256 GB
#
#                             GPU                     Processor Speed  \
# 0  Intel Iris Plus Graphics 655                  Max up to 3.80 GHz
# 1        Intel UHD Graphics 620  4.20 GHz (1.90 GHz Base Frequency)
# 2             Intel HD Graphics                            2.40 GHz
# 3         Intel HD Graphics 500                            2.40 GHz
# 4                    Integrated                    Minimum 1.40 GHz
#
#               Type         Release Year Maximum Resolution  \
# 0  Notebook/Laptop                 2021        2160 x 1440
# 1  Notebook/Laptop  Refurbished in 2023        1920 x 1080
# 2  Notebook/Laptop                 2019        1920 x 1080
# 3  Notebook/Laptop                  NaN         1366 x 768
# 4  Notebook/Laptop                 2015         1366 x 768
#
#                  Model               OS Hard Drive Capacity  \
# 0           CoreBook X  Windows 11 Home          512 GB SSD
# 1   Dell Latitude 7490   Windows 11 Pro                2 TB
# 2  Dell Latitude E5470   Windows 10 Pro              500 GB
# 3  HP Chromebook 11 G6        Chrome OS               16 GB
# 4       Various Models       Windows 10              NO HDD
#
#               Storage Type                                          Condition  \
# 0  SSD (Solid State Drive)  New: A brand-new, unused, unopened, undamaged ...
# 1  SSD (Solid State Drive)  Very Good - RefurbishedThe item shows minimal ...
# 2  SSD (Solid State Drive)  UsedAn item that has been used previously. The...
# 3                     eMMC  Good - RefurbishedThe item shows moderate wear...
# 4  SSD (Solid State Drive)  Good - RefurbishedThe item shows moderate wear...
#
#   Country Region Of Manufacture
# 0                         China
# 1                           USA
# 2                           USA
# 3                           USA
# 4                           USA

# %%
ebay_df.isna().sum() / len(ebay_df) * 100
# Out:
# Item Number                       0.000000
# Brand                             0.000000
# Processor                         1.006036
# Screen Size (in)                  0.000000
# Color                            47.937626
# Ram Size                         39.537223
# SSD Capacity                     26.156942
# GPU                              42.957746
# Processor Speed                  29.476861
# Type                             21.529175
# Release Year                     78.018109
# Maximum Resolution               36.167002
# Model                            17.152918
# OS                               20.271630
# Hard Drive Capacity              40.442656
# Storage Type                     33.903421
# Condition                        11.066398
# Country Region Of Manufacture     0.000000
# dtype: float64

# %%
ebay_df
# Out:
#       Item Number   Brand                     Processor  Screen Size (in)  \
# 0     85264981001   Chuwi                     Quad Core              14.0
# 1     85264981002    Dell        Intel Core i7 8th Gen.              14.0
# 2     85264981003    Dell           Intel Core i5-6300U              14.0
# 3     85264981004      Hp               Intel Celeron N              11.6
# 4     85264981005    Dell        Intel Core i5 6th Gen.              12.5
# ...           ...     ...                           ...               ...
# 3817  85264984787      Hp                   AMD Ryzen 5              14.0
# 3818  85264984788    Acer       Intel Core i5 11th Gen.              14.0
# 3820  85264984790    Dell  Intel Core i5 4th generation              12.5
# 3821  85264984791  Lenovo  Intel Core i5 6th generation              14.0
# 3823  85264984793    Dell        Intel Core i5 4th Gen.              14.0
#
#       Color Ram Size                           SSD Capacity  \
# 0      Gray     8 GB  1 Used,  1 support Max 1TB M.2 Extend
# 1     Black      NaN                                    NaN
# 2     Black    16 GB                                 500 GB
# 3     Black     4 GB                                    NaN
# 4       NaN     8 GB                                 256 GB
# ...     ...      ...                                    ...
# 3817    NaN     8 GB                                 512 GB
# 3818  Black    16 GB                                 256 GB
# 3820    NaN      NaN                                  240GB
# 3821    NaN      NaN                                  120GB
# 3823    NaN      NaN                                    NaN
#
#                                GPU                     Processor Speed  \
# 0     Intel Iris Plus Graphics 655                  Max up to 3.80 GHz
# 1           Intel UHD Graphics 620  4.20 GHz (1.90 GHz Base Frequency)
# 2                Intel HD Graphics                            2.40 GHz
# 3            Intel HD Graphics 500                            2.40 GHz
# 4                       Integrated                    Minimum 1.40 GHz
# ...                            ...                                 ...
# 3817       NVIDIA GeForce RTX 3050                            3.30 GHz
# 3818       Nvidia Geforce RTX 1650                            2.60 GHz
# 3820         Nvidia GeForce GT720M                            2.60 GHz
# 3821         Intel HD Graphics 620                            2.80 GHz
# 3823                           NaN                             2.50GHz
#
#                  Type         Release Year Maximum Resolution  \
# 0     Notebook/Laptop                 2021        2160 x 1440
# 1     Notebook/Laptop  Refurbished in 2023        1920 x 1080
# 2     Notebook/Laptop                 2019        1920 x 1080
# 3     Notebook/Laptop                  NaN         1366 x 768
# 4     Notebook/Laptop                 2015         1366 x 768
# ...               ...                  ...                ...
# 3817  Notebook/Laptop                  NaN                NaN
# 3818  Notebook/Laptop                 2021        1920 x 1080
# 3820  Notebook/Laptop                  NaN                 HD
# 3821  Notebook/Laptop                  NaN            Full HD
# 3823  Notebook/Laptop                  NaN                NaN
#
#                       Model               OS Hard Drive Capacity  \
# 0                CoreBook X  Windows 11 Home          512 GB SSD
# 1        Dell Latitude 7490   Windows 11 Pro                2 TB
# 2       Dell Latitude E5470   Windows 10 Pro              500 GB
# 3       HP Chromebook 11 G6        Chrome OS               16 GB
# 4            Various Models       Windows 10              NO HDD
# ...                     ...              ...                 ...
# 3817                    NaN  Windows 11 Home              512 GB
# 3818  Nitro 5 AN515-54-70KK       Windows 11              256 GB
# 3820                  E5440   Windows 11 Pro                  NO
# 3821                  T470s   Windows 11 Pro                  NO
# 3823                  E6320       Windows 10               320GB
#
#                  Storage Type  \
# 0     SSD (Solid State Drive)
# 1     SSD (Solid State Drive)
# 2     SSD (Solid State Drive)
# 3                        eMMC
# 4     SSD (Solid State Drive)
# ...                       ...
# 3817  SSD (Solid State Drive)
# 3818  SSD (Solid State Drive)
# 3820                      NaN
# 3821                      NaN
# 3823    HDD (Hard Disk Drive)
#
#                                               Condition  \
# 0     New: A brand-new, unused, unopened, undamaged ...
# 1     Very Good - RefurbishedThe item shows minimal ...
# 2     UsedAn item that has been used previously. The...
# 3     Good - RefurbishedThe item shows moderate wear...
# 4     Good - RefurbishedThe item shows moderate wear...
# ...                                                 ...
# 3817                                                NaN
# 3818  Used: An item that has been used previously. T...
# 3820  Used: An item that has been used previously. T...
# 3821  Used: An item that has been used previously. T...
# 3823  UsedAn item that has been used previously. The...
#
#      Country Region Of Manufacture
# 0                            China
# 1                              USA
# 2                              USA
# 3                              USA
# 4                              USA
# ...                            ...
# 3817                           USA
# 3818                        Taiwan
# 3820                           USA
# 3821                         China
# 3823                           USA
#
# [1988 rows x 18 columns]

# %% [markdown]
# Working with the Model column

# %%
ebay_df['Model'] = ebay_df['Model'].str.title()
ebay_df['Model'] = ebay_df['Model'].str.strip()
ebay_df['Model'] = ebay_df['Model'].replace(to_replace='Chromebooks', value='Chromebook')
ebay_df = ebay_df[ebay_df['Model'] != 'Does Not Apply']
ebay_df = ebay_df[ebay_df['Model'].notna()]
ebay_df
# Out:
#       Item Number   Brand                     Processor  Screen Size (in)  \
# 0     85264981001   Chuwi                     Quad Core              14.0
# 1     85264981002    Dell        Intel Core i7 8th Gen.              14.0
# 2     85264981003    Dell           Intel Core i5-6300U              14.0
# 3     85264981004      Hp               Intel Celeron N              11.6
# 4     85264981005    Dell        Intel Core i5 6th Gen.              12.5
# ...           ...     ...                           ...               ...
# 3816  85264984786    Dell                           NaN              14.0
# 3818  85264984788    Acer       Intel Core i5 11th Gen.              14.0
# 3820  85264984790    Dell  Intel Core i5 4th generation              12.5
# 3821  85264984791  Lenovo  Intel Core i5 6th generation              14.0
# 3823  85264984793    Dell        Intel Core i5 4th Gen.              14.0
#
#       Color Ram Size                           SSD Capacity  \
# 0      Gray     8 GB  1 Used,  1 support Max 1TB M.2 Extend
# 1     Black      NaN                                    NaN
# 2     Black    16 GB                                 500 GB
# 3     Black     4 GB                                    NaN
# 4       NaN     8 GB                                 256 GB
# ...     ...      ...                                    ...
# 3816    NaN      NaN                                    NaN
# 3818  Black    16 GB                                 256 GB
# 3820    NaN      NaN                                  240GB
# 3821    NaN      NaN                                  120GB
# 3823    NaN      NaN                                    NaN
#
#                                GPU                     Processor Speed  \
# 0     Intel Iris Plus Graphics 655                  Max up to 3.80 GHz
# 1           Intel UHD Graphics 620  4.20 GHz (1.90 GHz Base Frequency)
# 2                Intel HD Graphics                            2.40 GHz
# 3            Intel HD Graphics 500                            2.40 GHz
# 4                       Integrated                    Minimum 1.40 GHz
# ...                            ...                                 ...
# 3816                           NaN                                 NaN
# 3818       Nvidia Geforce RTX 1650                            2.60 GHz
# 3820         Nvidia GeForce GT720M                            2.60 GHz
# 3821         Intel HD Graphics 620                            2.80 GHz
# 3823                           NaN                             2.50GHz
#
#                  Type         Release Year Maximum Resolution  \
# 0     Notebook/Laptop                 2021        2160 x 1440
# 1     Notebook/Laptop  Refurbished in 2023        1920 x 1080
# 2     Notebook/Laptop                 2019        1920 x 1080
# 3     Notebook/Laptop                  NaN         1366 x 768
# 4     Notebook/Laptop                 2015         1366 x 768
# ...               ...                  ...                ...
# 3816  Notebook/Laptop                  NaN        1920 x 1080
# 3818  Notebook/Laptop                 2021        1920 x 1080
# 3820  Notebook/Laptop                  NaN                 HD
# 3821  Notebook/Laptop                  NaN            Full HD
# 3823  Notebook/Laptop                  NaN                NaN
#
#                       Model               OS Hard Drive Capacity  \
# 0                Corebook X  Windows 11 Home          512 GB SSD
# 1        Dell Latitude 7490   Windows 11 Pro                2 TB
# 2       Dell Latitude E5470   Windows 10 Pro              500 GB
# 3       Hp Chromebook 11 G6        Chrome OS               16 GB
# 4            Various Models       Windows 10              NO HDD
# ...                     ...              ...                 ...
# 3816   Dell Precision M4600              NaN                 NaN
# 3818  Nitro 5 An515-54-70Kk       Windows 11              256 GB
# 3820                  E5440   Windows 11 Pro                  NO
# 3821                  T470S   Windows 11 Pro                  NO
# 3823                  E6320       Windows 10               320GB
#
#                  Storage Type  \
# 0     SSD (Solid State Drive)
# 1     SSD (Solid State Drive)
# 2     SSD (Solid State Drive)
# 3                        eMMC
# 4     SSD (Solid State Drive)
# ...                       ...
# 3816                      NaN
# 3818  SSD (Solid State Drive)
# 3820                      NaN
# 3821                      NaN
# 3823    HDD (Hard Disk Drive)
#
#                                               Condition  \
# 0     New: A brand-new, unused, unopened, undamaged ...
# 1     Very Good - RefurbishedThe item shows minimal ...
# 2     UsedAn item that has been used previously. The...
# 3     Good - RefurbishedThe item shows moderate wear...
# 4     Good - RefurbishedThe item shows moderate wear...
# ...                                                 ...
# 3816  For parts or not working: An item that does no...
# 3818  Used: An item that has been used previously. T...
# 3820  Used: An item that has been used previously. T...
# 3821  Used: An item that has been used previously. T...
# 3823  UsedAn item that has been used previously. The...
#
#      Country Region Of Manufacture
# 0                            China
# 1                              USA
# 2                              USA
# 3                              USA
# 4                              USA
# ...                            ...
# 3816                           USA
# 3818                        Taiwan
# 3820                           USA
# 3821                         China
# 3823                           USA
#
# [1642 rows x 18 columns]

# %%
ebay_df.isna().sum() / len(ebay_df) * 100
# Out:
# Item Number                       0.000000
# Brand                             0.000000
# Processor                         0.974421
# Screen Size (in)                  0.000000
# Color                            38.367844
# Ram Size                         29.049939
# SSD Capacity                     12.971985
# GPU                              31.973203
# Processor Speed                  16.321559
# Type                              7.734470
# Release Year                     74.056029
# Maximum Resolution               24.238733
# Model                             0.000000
# OS                                6.090134
# Hard Drive Capacity              29.415347
# Storage Type                     22.168088
# Condition                        12.241169
# Country Region Of Manufacture     0.000000
# dtype: float64

# %%
ebay_df['Model'].unique()
# Out:
# array(['Corebook X', 'Dell Latitude 7490', 'Dell Latitude E5470',
#        'Hp Chromebook 11 G6', 'Various Models', 'Chromebook C738T-C44Z',
#        'Hp Chromebook 11 G5', 'Chromebook C720-2848',
#        'Dell Latitude 7480', 'Samsung Chromebook 3', 'Lenovo T480',
#        'Acer Chromebook 311', 'Chuwi Lapbook Pro', 'Chuwi Corebook X',
#        'Dell Latitude 5289', 'Dell Latitude E5500', 'Dell Latitude 3189',
#        'Acer Chromebook C731', 'Dell Latitude 7400', '16 Plus 7630',
#        'Dell Inspiron 14 5425', 'Hp Elite X2 G4',
#        'Microsoft Surface Pro 3', 'Lenovo 100E', 'Hp 15 Essential',
#        'Dell Latitude 5580', 'Gemibook Plus', 'Hp Elitebook 840 G6',
#        'Yoga 11E 3Rd Gen.', 'Hp Probook 650 G3',
#        'Lenovo Legion 5 Pro 16Iah7', 'Lenovo Thinkpad T440', 'E5580',
#        'Dell Latitude E5440', 'Chuwi Freebook', 'L380',
#        'Dell Inspiron 15 3535', '5414', '17Zb90R-K.Aac7U1',
#        'Hp T4M32Ut#Aba', 'Probook 650 G2', 'Dell Latitude E5550',
#        'Chromebook 11 G6 Ee', 'Microsoft Surface Pro',
#        'Samsung Chromebook', 'Chromebook 11A G8 Ee',
#        'Dell Latitude E7270', 'Lenovo Thinkpad X220',
#        'Microsoft Surface Book', 'Dell Inspiron 15 7000',
#        'Dell Latitude 7280', 'Dell 5470', 'Dell Chromebook 3380',
#        'Lenovo Yoga', 'Lenovo Ideapad 3I', 'Toshiba Qosmio',
#        'Latitude E7470', 'Dell Precision 5510', 'Dell 3301',
#        'Hp Elitlebook G5', 'Lenovo Thinkpad X230',
#        'Microsoft Surface Pro 7', 'Dell Latitude Rugged 5414', 'X15',
#        'Hp 15-Fa1093Dx', '5410', 'Hp Zbook Studio G3',
#        'Lenovo Thinkpad X1 Yoga', 'Panasonic Cf-33', 'Dell Latitude 5480',
#        'Lenovo Thinkpad L390', 'Probook 650 G5', 'Lenovo Thinkpad T480S',
#        'Asus Vivobook', 'Dell Latitude 3410',
#        'Hp Elitebook Revolve 810 G2', 'Xo-1', 'C731T-C0X8',
#        'Dell 3190 2-In-1', 'Hp Probook', 'Lenovo Ideapad 1',
#        'Hp Chromebook X360 11 G1 Ee', 'Dell Latitude 7390',
#        'Latitude 14 Rugged (5404)', 'Hp Compaq 6910P', 'Thinkpad T480S',
#        'Lenovo Thinkpad L13 Yoga', 'Lenovo Flex 5', 'E5440',
#        'Dell Precision M4600', 'E7270', 'Acer Swift 1', 'F146',
#        'Latitude 12 7202 Rugged Outdoor Tablet', 'Microsoft Surface 1769',
#        '15-Dy2795Wm', 'E736', 'Lenovo Ideapad Flex 5 14Iru8', 'Dell 9570',
#        'T430', 'Lifebook S781', 'E734', 'Dell Latitude E6430',
#        'Dell Latitude E6440', '13', 'T470', 'A574', 'E7450', 'E570',
#        'T460', 'Dell Latitude E5520', 'Hp Victus 15', 'E544',
#        'Hp Spectre X360', 'T470S', 'Latitude 5400', 'E6430', 'V15 G3',
#        'E5430', 'L560', 'Lenovo Ideapad 3 15Iau7', 'A315-24Pt-R90Z',
#        'Acer C731', 'Acer Aspire 3', 'Lenovo Thinkpad L480', 'Lg Gram',
#        'Lenovo Thinkpad X390', 'Hp Revolve 810 G2',
#        'Microsoft Surface Laptop 4', 'Dell Precision 7510',
#        'Elitebook 840 G5', 'Latitude 5401', 'Asus Vivobook Flip 14',
#        'Lenovo Thinkpad X280', 'Elitebook 845 G8', 'Dell Xps 15 7590',
#        'Lenovo Ideapad Flex 5 14Itl05', 'Lenovo E590',
#        'Lenovo Thinkpad T450', '17B', 'Microsoft Surface Laptop 3',
#        '11 Pro 7130', 'T440S', 'Panasonic Toughbook Cf-54',
#        '12 Rugged Tablets', 'Acer Chromebook R11', 'X240', 'E6520',
#        'Elitebook X360 1030 G2', '3330', 'E546', 'Dell Latitude E7450',
#        '81Yd', 'Pp-9347', 'E744', 'X260', 'Dell Latitude',
#        'Dell Precision 5520', 'Samsung Chromebook 11', 'Hp Pro C640',
#        'Alienware M18', 'Dell Xps 13 9370', 'Alienware 18',
#        'Lenovo Ideapad Flex 5 Chrome 13Itl6', 'Lenovo Thinkpad P50',
#        'Dell Inspiron 3593', 'Dell 5414', 'Dell Precision 7540',
#        'Hp Notebook 15-Bs0Xx', 'Dell Latitude E6400',
#        'Lenovo Thinkpad W520', 'Latitude 5400 Chrome',
#        'Dell Inspiron 15 3520', 'Lenovo X1 Carbon', 'Iii Maestro E-Book',
#        'K55A', 'Dell Inspiron 3530', 'Thinkpad T460P',
#        'Chromebook 2 Xe500C12', 'Hp Zbook 17 G5', '81Mc004Wus', 'Gram',
#        'Vaio Vwnc51427-Bk', 'Lenovo Yoga 6', 'Lenovo Thinkpad Yoga 11E',
#        'Lenovo Thinkbook 15 G2', 'Hp Victus', 'Gpd Pocket', 'T460S',
#        'M30-70', 'Dell Latitude E5450', 'X40-D-123',
#        'Lenovo Thinkpad X240', 'Surfacebook 2Nd Gen', 'E6540', '2 Pros',
#        '11 Pro 7139', '82C5', 'Dell Inspiron 13 7359', 'E5470',
#        'Lenovo Thinkpad T440S', 'Lenovo Thinkpad T460', 'Lp156Wh4 Tl A1',
#        'Acer Travelmate', 'Lenovo Thinkpad T470S', 'Acer Chromebook 15',
#        'Microsoft Surface Go', 'E540', 'Lenovo Thinkpad X260',
#        'Dell 3189 2 In 1', 'Microsoft Surface Laptop',
#        'Apple Macbook Pro 15"', 'Dell Latitude 5490',
#        'Dell Latitude E5420', 'Hp 15 Dw0083Wm', 'Chromebook 14 G5',
#        'Dell Latitude E7440', 'Dell Latitude D630', 'Dell Latitude E5430',
#        'Lenovo Thinkpad T14', 'Lg Gram 17', 'Acer Chromebook Spin 713',
#        'Acer Switch Alpha 12', 'Ideapad Flex 5 14Iil05',
#        'Dell Inspiron 15 3565', 'Air', 'Hp Probook 6465B',
#        'Dell Precision 7720', 'Dell Latitude 3570', '14', 'Pro 1St Gen',
#        'Dell Latitude 6410U', 'Hp Probook 640 G2', 'Vostro 5471',
#        'Microsoft Surface Book 3', 'Acer Chromebook 11',
#        'Hp Probook 650 G4', 'Hp Probook 6570B', 'Sgin X15',
#        'R12 Ix 125R1', 'Sgin-M15P', 'Sgin M17Pro', 'Lenovo N22',
#        'Lenovo Thinkpad Edge', 'Hp Stream', 'Dell Latitude E6410',
#        'X7-Z8700', 'Hp Chromebook', 'Google Pixelbook Go',
#        'Google Pixel Tablet Ga04754-Us', 'Precision 7750',
#        'Msi Cyborg 15', 'Hp Elitebook 860 G9', 'Chromebook 14E', '3190',
#        'Lenovo Thinkpad L14 Gen1', 'Hp 15-Dy2152Wm', 'Dell Latitude 5590',
#        'Lenovo Ideapad P580', 'Lenovo 15Iil05', 'Acer Aspire V3-571G',
#        'Gateway I5-12Th', '15-Da0041Dx', 'Acer Travelmate-P 645-M',
#        'I5-4300Y', 'Dell Latitude E4310', 'Lenovo Thinkpad T490S',
#        'Dell Latitude E7470', 'Lenovo Thinkpad T420', '14-Ca061Dx',
#        'Hp 840 G1', 'Dell Latitude 3350', 'Samsung Galaxy Chromebook Go',
#        'Latitude 5430 Rugged', 'Latitude 7230 Rugged Extreme Tablet',
#        'Toshiba Tecra', 'Dell Inspiron 17 3793',
#        'Microsoft Surface Pro X', 'Lenovo Thinkpad X1 Tablet Gen 3',
#        'Hp Probook 4540S', '7480', 'Dell Latitude 5520', 'Hp Pavilion 15',
#        'Acer Nitro 5', 'Envy 17 17T', 'Chromebook', 'Dell Latitude 7420',
#        'Hp Elitebook Folio 9470M', 'Hp Elitebook X360 1040 G7',
#        'Ideapad 3', 'Thinkpad T14S Gen 1', 'Hp Probook 450 G3',
#        'Latitude 7420', '2', 'Gateway Gwnr71517-Bl', 'Acer Chromebook',
#        'Precision 7740', 'Samsung 700T', 'Dell Latitude E7480',
#        'Hp Chromebook 11 G4', 'Thinkpad E485', '82R',
#        'Dell Latitude 5400', 'Elitebook 820 G3 Windows 7',
#        'Samsung Galaxy Book', 'Dell Latitude E7480 7480 E7280 7280',
#        'Dell Chromebook 11 3120', 'Hp 17-Cn3097Nr',
#        'Lenovo N23 Chromebook', 'E5530', 'Samsung Galaxy Chromebook 4K',
#        'Hp Probook 4430S', '11A G6 Ee', 'Lenovo Thinkpad 13 Chromebook',
#        'Lenovo Flex 3', 'Lenovo Thinkpad T540P', 'Asus Vivobook Flip',
#        'Dell Latitude 5175', 'Dell Latitude 5440', 'Dell Precision 7710',
#        'Hp Zbook 14U G5', 'Latitude 14 Rugged Extreme 7404', 'Thinkpad',
#        'E7470', 'Lenovo Thinkpad W530', 'Lenovo Thinkpad P51',
#        'Hp Elitebook 840 G8', 'Hp Pavilion X360 14-Dw1013Dx',
#        'Dell Chromebook 11 3180', 'Panasonic Toughpad Fz-Q2',
#        'Dell Precision 5530', 'Fujitsu Quaderno A4 (2Nd Gen.)',
#        'Apple Macbook Pro 13"', '47X83Ua#Aba', 'Dell Inspiron 15 3000',
#        'Hp Elitebook 8560P', 'Dell Precision 15 5550',
#        'Lenovo Thinkpad T580', 'F110 G3',
#        'Hp Zbook Firefly 14 G7 Mobile Workstation', 'Hp Chromebook 14 G5',
#        'Gateway Gwnc31514-Bl', 'Yoga 11E', 'Hp Omen', '7530',
#        'Lenovo Thinkpad X1', 'Chuwi Minibook X', 'Hp Envy X360',
#        'Precision 5760 Laptop', 'Hp Elitebook 840', 'Inspiron 3420',
#        'Lenovo Yoga 7 16Arp8', 'Lenovo Thinkpad E15', 'Hp Mini 1104',
#        'Latitude 7490', 'Hp Pro X2 612', 'Lifebook T939',
#        'Latitude E5470', 'Dell Latitude 5490 7490',
#        'Dell Latitude 5490 7490 7400 7000', 'Microsoft Surface Book 2',
#        'Dell Latitude 3190', 'I7630-7619Slv-Pus',
#        'Microsoft Surface Go 3', 'Lenovo 14E Chromebook',
#        'Hp Victus 15-Fb1013Dx', 'Lenovo Thinkpad Yoga 370',
#        'Lenovo Thinkpad L380', 'Panasonic Toughpad Fz-G1',
#        'Hp Probook X360 11 G1 Ee', 'Chuwi Herobook Pro',
#        'Dell Inspiron 16 Plus 7630', 'Google Pixel Slate', '16Iah7',
#        'Acer Chromebook R 13', 'Hp 810 G1',
#        'Dell Latitude 7220 Rugged Extreme Tablet', 'Ax201Ngw',
#        'Dell Latitude 7410', 'Gwtc71427-Bk', 'Dell Xps 13 9310',
#        'Chromebook Plus Xe513C24', 'Latitude E6420', 'Dell Latitude D810',
#        'Dell Chromebook 11 3189', 'Lenovo Thinkpad X1 Yoga (3Rd Gen)',
#        'Lenovo Yoga 7I', 'Gdp Pocket 2', 'Galaxy Chromebook Go Xe345Xda',
#        'Lenovo Thinkpad X1 Yoga (4Th Gen)', 'Gobi3000', 'Probook 440 G10',
#        'Craig Clp281X', 'B300', 'Hp Elitebook 840 G8 11Th',
#        'Hp Chromebook 11 G7 Ee', '5580', 'Lenova Yoga',
#        'Lenovo Ideapad 3', 'Matebook D15 11Th Gen', 'Hp Elitebook 850 G3',
#        'Hp Elitebook 8540W', 'Lenovo L14 11Gen', 'Thinkpad T470 I7-7600U',
#        'Gateway Gwtn141-10Gr', 'Dell Latitude 15 5580',
#        'Asus Transformer Book', 'Fx505Dt', 'D620, D630, E5500 Or Similar',
#        '17T-Cto', 'Hp Zbook 17 G4', 'Microsoft Surface Pro 7+',
#        'Lenovo Chromebook 82C1', 'Dell Latitude E6330', 'Panasonic Fz-G1',
#        'Lenovo Chromebook 14E', 'Lenovo Thinkpad T480', 'Metabox N850Hj',
#        'Chuwi Ubook Xpro', 'Fujitsu Lifebook U729', 'Fujitsu',
#        'Lenovo 300E Winbook', 'Dell Xps 13',
#        'Dell Latitude 7414 Rugged Extreme', 'Acer Chromebook 514',
#        'Alienware M15 R7', 'Hp Pavilion X360', 'Lenovo Ideapad 100S',
#        'Sl10W47275', 'Kano Pc', 'Hp Elitebook 840 G5',
#        'Lenovo Thinkpad A485', 'Hp Elite Dragonfly',
#        'Hp Premium Flagship Laptop', 'E6400', 'Precision 7680',
#        'Dell Latitude 3540', 'Hp Chromebook X360',
#        'Lenovo Ideapad Flex 5 Cb', '3180',
#        'Lenovo Thinkpad X1 Carbon Gen 11', 'Panasonic Toughbook Cf-33',
#        'Thinkpads', 'Lenovo Thinkpad T530', 'Asus Q534U',
#        'Lenovo Thinkpad E590', 'Ibm T22', 'Dell Latitude E5570',
#        'Elitebook 840 G3', 'Chromebook 11 3180', 'Pavilion X360',
#        'Toshiba Nb505-N508Bl', 'Wyse 5470', 'Dell Inspiron 7573',
#        '14Dq0052Dx', 'Dell Chromebook', 'Lenovo Thinkbook 14 G4',
#        'Lenovo 100E Chromebook', 'Chromebook 11 G6 Ee (3Nu57Ut#Aba)',
#        'Dell Vostro 7620', 'Libreboot T440P', 'Hp Pavilion Dv4',
#        'Lenovo Thinkpad X1 6Th Gen', 'Dell Latitude 14 Rugged Extreme',
#        'Dell Xps 13 9360', '81M9', '17T-Cr000', 'Lenovo Thinkpad E14',
#        'Dell Latitude 7290', 'Cf-Sz5Pdyvs', 'Flex 5 14Iau7', 'Ba',
#        'Dell Duo', 'Lenovo Thinkpad T490', 'Huawei Matebook D 16 2024',
#        'Dell 7300', 'Stream 11-D010Wm', 'Acer Chromebook Spin 511',
#        'Acer Chromebook Spin 513', 'Dell Xps 9315',
#        'Thinkpad X1 Yoga 3Rd Gen 20Ld', 'Dell Chromebook 11 3100',
#        'Hp Elitebook 845 G8', 'Apple Macbook Air 11"',
#        'Thinkpad 11E Chromebook', 'R515Ma-Rh01',
#        'Lenovo N23 Yoga Chromebook', 'Hp Elitebook 840 G4',
#        'Hp Notebook 17-By4063Cl', 'Dell Laptop', 'Hp 17-By2Xxx',
#        'Xe310Xba-Kc2Us', 'Asus Rog G74S', 'Dell 5559',
#        'Dell Inspiron 15 3593', 'Dell Inspiron 7620', '80Ys000Cus',
#        'Hp Elitebook 830 G5', 'Panasonic Toughbook Cf-D1',
#        'Hp Chromebook 14 G4', 'Cm3200Fm1A-Ws44T',
#        'Latitude 13 7330 Rugged Extreme', 'Probook 11 G1',
#        'Lenovo Thinkpad X1 Yoga (6Th Gen)', 'Latitude 7200',
#        'Hp Elite X360 830 G9', 'Samsung Chromebook Plus', 'Latitude 3390',
#        'Dell Precision 5550', 'Latitude 3510', 'Lenovo Thinkpad T410',
#        'Dell Latitude 7470', 'Dell Latitude 5491', 'Dell Latitude E5540',
#        'Thinkpad T14S', 'Dell Lat 5590 I5-8350U', 'Thinkpad T490S',
#        'Chromebook G3 Cd570M-A1', 'Lenovo Yoga 3 Pro',
#        'Lenovo Thinkpad 13', 'Cf-Sv7Rdavs', 'Elitebook',
#        'Lenovo Thinkpad T430', 'Chromebook N21', 'Z500.I7 3Rd Gen',
#        'Hp 14 G4', 'Gateway Ggnc51518', 'Hp 15-Dw1083Wm', 'Thinkpad E15',
#        'Panasonic Toughpad Fz-G1 Mk3', 'Ubook X', 'Chromebook C738T',
#        'Samsung Galaxy Book Go', 'Hp 840 G3', 'Lenovo Thinkpad P1',
#        'Getac V110 G3 I5-6200U', 'Hp Mini 5103', 'Lenovo T495',
#        'Lenovo Thinkpad T14 4Th Gen.', 'Lenovo Slim 7 Prox 14Arh7',
#        'Herobook Pro', 'Dell Chromebook 3189', 'Latitude E6420/6430',
#        'Lenovo Ideapad 5', 'Acer Aspire 1',
#        'Dell Latitude 14 Rugged 5414', 'Core I5',
#        'Acer Chromebook Spin 11 R751Tn', '15-Ba018Wm',
#        'Dell Precision 3520', 'S5 Max', 'Samsung Chromebook 4+',
#        'Dell Latitude 3490', 'Chromebook 11 C771-C4Tm',
#        'Hp Chromebook 14A G5', 'Dell Latitude E5270',
#        'Dell Precision 3540', 'Google Pixelbook', 'Elitebook 820 G2',
#        'Acer Chromebook N18Q12', 'Samsung Series 7',
#        'Hp Elitebook 850 G4', 'Thinkpad X1 Carbon', 'Inspiron 15 3543',
#        'Lenovo Thinkpad X1 Yoga (5Th Gen)', 'Dell Latitude 5401',
#        'Lenovo Ideapad S340', 'R8300', 'Dell Latitude 7390 2-In-1',
#        'Hp 14-Dq2032Wm', 'Lenovo Chromebook N40-20',
#        'Dell Precision M2800', 'Lenovo Thinkpad T510',
#        'Dell Inspiron 15 3530', 'Lenovo Thinkpad T470',
#        'Dell Xps 15 9560', 'Asus Chromebook', 'Thinkpad X280',
#        'Dell Latitude E6420', 'Dell Latitude 14 3420', 'X555La',
#        'Chromebook C720-2844', 'Asus Rog Zephyrus', 'Thinkpad T495',
#        'Latitude 3379', 'Dell E5530', 'Gigabyte Aero 15 Kd-72Us624Sp',
#        'Elitebook 840 G6', 'Zbook 14U G6', 'Acer Aspire 5 A515',
#        'Lenovo Ideapad Duet 3 10Igl5', 'Hp Elitebook X360 1030 G4',
#        'Dell Xps 13 9380', 'Sgin-M15', '79T1D', 'N16Q13',
#        'Asus Rog Strix Scar 18', 'Hp Notebook 15-Ba079Sa',
#        'Acer Chromebook C720', 'Lenovo V330-15Ikb', 'Msi Ge Series',
#        'Dell Latitude E6230', 'Hp Stream 11-R015Wm', 'Latitude E5440',
#        'Dell Latitude E6530', 'Hp 15-Bs212Wm', 'X201',
#        'Dell Latitude Xt2', 'Dell Latitude E6500',
#        'Hp Probook Fortis 14 Inch G9', 'Core I3', 'Dell Latitude 5420',
#        'P22T001', 'Lenovo Thinkpad E585', 'Hp Elitebook Revolve 810 G3',
#        'Asus Vivobook Pro 14 Oled', 'C731T', 'Chromebook Flip C100',
#        'X1 Carbon 9 Gen', 'Hp 15-G012Dx', 'Dell Latitude E6400 Xfr',
#        '14 G6', 'Acer Aspire E 15', 'Razer Blade', 'Hp 850 G2',
#        'Core I7-1165U', 'Asus Zenbook Pro 16X', 'N550J',
#        'Hp Zbook 15U G3', 'Toshiba Satellite L25-S119',
#        'Chromebook 100S 80Qn 11Iby', 'Spectre X360 15-Eb0043Dx',
#        'Hp Elitebook 745 G5', 'T50', 'Dell Latitude E7250',
#        'Lenovo Ideapad Gaming 3', 'Lenovo Thinkpad T440P', 'G75V',
#        'Asus Chromebook Flip', 'Hp Elitebook 8460P', '7290',
#        'Alienware 14', 'Latitude E5430', 'Acer Chromebook Cb314',
#        'Latitude D820', '20Ny-S3Y600', 'Hp Probook 440 G3',
#        'Toughbook Cf-52', 'Lenovo Thinkpad L15 Gen 2', 'Inspiron',
#        'Dell 3300', 'Lenovo Thinkpad T430S', '100E Chromebook',
#        'Acer C740', 'Microsoft Surface Pro 6', '17Z90Q-K',
#        'Lenovo Thinkpad X1 Carbon', 'Samsung Np-Q1U',
#        'Dell Latitude 7300', 'Gateway Ultra Slim Gwtn156-11Bl',
#        'Lenovo Thinkpad X1 Carbon 4Th Gen', 'Surface Pro 7', 'Wcb5000',
#        'G512Lw-Ws74', 'Lenovo Ideapad L340', 'Hp Chromebook 14 G1',
#        'Hp 14" Touchscreen', '14-An013Nr', 'Asus Vivobook K1703Z',
#        'Nx.G55Aa.010', '5404 I5-4310', 'Dell Inspiron 1501', 'Dell 5510',
#        'Chromebook C202Sa', 'Hp Stream 15-Bw053Od', 'Envy 17T-Cw000',
#        'Chromebook 11 G4', 'Hp Elitebook 830 G7 Notebook Pc',
#        'Lenovo Chromebook C340-11', 'Thinkbook 14 G3',
#        'Lenovo Thinkpad T470, T470', 'Hp Elitebook 850 G2',
#        'Dell Latitude 7320', 'Dell Latitude 16 7640', 'T530',
#        'Hp Probook 645 G3', 'Inspiron 5630 Laptop', '2767-11Y',
#        'Dell Latitude 3310 2-In-1', 'Hp 15-Fd0083Wm', 'Hp Probook 450 G2',
#        'Lenovo Thinkpad E14 Gen 2', 'Dell Inspiron 14 7405 2 In 1',
#        'Cf-53', 'T60', 'Dell Inspiron 3558', 'Elite X2 1013 G3',
#        'Precision 7510', 'Dell Inspiron 15 3552', '15-Dy5131Wm',
#        'Dell D830', 'I7', 'Hp Elitebook 840 G3', 'Hp 14A G5',
#        'Hp 14-Dq2053Cl', 'Hp 15-Bw071Nr', 'Dell Inspiron 5767',
#        'Hp Probook 640 G1', 'Nitro 5 An515-54-70Kk', 'E6320'],
#       dtype=object)

# %%
mask = ebay_df['Release Year'].isna()
missing_year = ebay_df[mask]
len(missing_year['Model'].unique())
# Out:
# 505

# %%
missing_years = list(missing_year['Model'].unique())
first_half = missing_years[0:253]
len(first_half)
# Out:
# 253

# %%
second_half = missing_years[253:505]
len(second_half)
# Out:
# 252

# %%
first_half
# Out:
# ['Hp Chromebook 11 G6',
#  'Chromebook C720-2848',
#  'Dell Latitude 7480',
#  'Lenovo T480',
#  'Dell Latitude 5289',
#  'Dell Latitude E5500',
#  'Dell Inspiron 14 5425',
#  'Microsoft Surface Pro 3',
#  'Lenovo 100E',
#  'Yoga 11E 3Rd Gen.',
#  'Hp Probook 650 G3',
#  'Chuwi Lapbook Pro',
#  'Lenovo Thinkpad T440',
#  'E5580',
#  'L380',
#  '17Zb90R-K.Aac7U1',
#  'Hp T4M32Ut#Aba',
#  'Probook 650 G2',
#  'Dell Latitude E5550',
#  'Microsoft Surface Pro',
#  'Samsung Chromebook',
#  'Chromebook 11A G8 Ee',
#  'Lenovo Thinkpad X220',
#  'Microsoft Surface Book',
#  'Dell Inspiron 15 7000',
#  'Dell Latitude 7280',
#  'Dell 5470',
#  'Lenovo Yoga',
#  'Toshiba Qosmio',
#  'Latitude E7470',
#  'Dell Precision 5510',
#  'Dell 3301',
#  'Lenovo Thinkpad X230',
#  'Dell Latitude Rugged 5414',
#  '5410',
#  'Hp Zbook Studio G3',
#  'Dell Latitude 5480',
#  'Probook 650 G5',
#  'Lenovo Thinkpad T480S',
#  'Asus Vivobook',
#  'Dell Latitude 3410',
#  'Hp Elitebook Revolve 810 G2',
#  'Xo-1',
#  'Dell 3190 2-In-1',
#  'Hp Probook',
#  'Lenovo Ideapad 1',
#  'Hp Chromebook X360 11 G1 Ee',
#  'Dell Latitude 7390',
#  'E5440',
#  'Dell Precision M4600',
#  'E7270',
#  'Acer Swift 1',
#  'F146',
#  'Latitude 12 7202 Rugged Outdoor Tablet',
#  'Microsoft Surface 1769',
#  'E736',
#  'Dell 9570',
#  'T430',
#  'Lifebook S781',
#  'E734',
#  'Dell Latitude E6430',
#  'Dell Latitude E6440',
#  '13',
#  'T470',
#  'A574',
#  'E7450',
#  'E570',
#  'T460',
#  'Dell Latitude E5520',
#  'E544',
#  'Hp Spectre X360',
#  'T470S',
#  'E6430',
#  'V15 G3',
#  'E5430',
#  'L560',
#  'A315-24Pt-R90Z',
#  'Acer C731',
#  'Dell Latitude 7490',
#  'Acer Aspire 3',
#  'Lenovo Thinkpad L480',
#  'Lg Gram',
#  'Lenovo Thinkpad X390',
#  'Hp Revolve 810 G2',
#  'Dell Precision 7510',
#  'Panasonic Cf-33',
#  'Latitude 5401',
#  'Asus Vivobook Flip 14',
#  'Lenovo Thinkpad X280',
#  'Elitebook 845 G8',
#  'Dell Xps 15 7590',
#  'Lenovo E590',
#  'Lenovo Thinkpad T450',
#  '11 Pro 7130',
#  'T440S',
#  'Panasonic Toughbook Cf-54',
#  '12 Rugged Tablets',
#  'Acer Chromebook R11',
#  'X240',
#  'E6520',
#  'Elitebook X360 1030 G2',
#  '3330',
#  'E546',
#  'Dell Latitude E7450',
#  '81Yd',
#  'Pp-9347',
#  'E744',
#  'X260',
#  'Dell Latitude',
#  'Dell Precision 5520',
#  'Samsung Chromebook 11',
#  'Hp Pro C640',
#  'Dell Xps 13 9370',
#  'Lenovo Thinkpad P50',
#  'Dell 5414',
#  'Dell Precision 7540',
#  'Hp Notebook 15-Bs0Xx',
#  'Dell Latitude E6400',
#  'Lenovo Thinkpad W520',
#  'Latitude 5400 Chrome',
#  'Lenovo X1 Carbon',
#  'Microsoft Surface Laptop 4',
#  'Iii Maestro E-Book',
#  'K55A',
#  'Thinkpad T460P',
#  'Chromebook 2 Xe500C12',
#  'Hp Zbook 17 G5',
#  'Vaio Vwnc51427-Bk',
#  'Lenovo Yoga 6',
#  'Lenovo Thinkbook 15 G2',
#  'Hp Victus',
#  'Gpd Pocket',
#  'Dell Latitude E5470',
#  'T460S',
#  'M30-70',
#  'X40-D-123',
#  'Lenovo Thinkpad X240',
#  'Surfacebook 2Nd Gen',
#  'E6540',
#  '2 Pros',
#  '11 Pro 7139',
#  'Dell Latitude E5450',
#  '82C5',
#  'Dell Inspiron 13 7359',
#  'E5470',
#  'Lp156Wh4 Tl A1',
#  'Acer Travelmate',
#  'Lenovo Thinkpad T470S',
#  'Acer Chromebook 15',
#  'Microsoft Surface Go',
#  'E540',
#  'Lenovo Thinkpad X260',
#  'Microsoft Surface Laptop',
#  'Apple Macbook Pro 15"',
#  'Dell Latitude 5490',
#  'Dell Latitude 7400',
#  'Dell Latitude E5420',
#  'Hp 15 Dw0083Wm',
#  'Chromebook 14 G5',
#  'Dell Latitude E7440',
#  'Dell Latitude E5430',
#  'Lenovo Thinkpad T14',
#  'Lg Gram 17',
#  'Acer Chromebook Spin 713',
#  'Acer Switch Alpha 12',
#  'Dell Inspiron 15 3565',
#  'Air',
#  'Hp Probook 6465B',
#  'Dell Precision 7720',
#  '14',
#  'Pro 1St Gen',
#  'Dell Latitude 6410U',
#  'Hp Probook 640 G2',
#  'Vostro 5471',
#  'Microsoft Surface Book 3',
#  'Hp Probook 650 G4',
#  'Hp Probook 6570B',
#  'R12 Ix 125R1',
#  'Dell Latitude 5580',
#  'Lenovo N22',
#  'Lenovo Thinkpad Edge',
#  'Hp Stream',
#  'Dell Latitude E6410',
#  'X7-Z8700',
#  'Precision 7750',
#  'Msi Cyborg 15',
#  'Hp Elitebook 860 G9',
#  '3190',
#  'Hp 15-Dy2152Wm',
#  'Dell Latitude 5590',
#  'Lenovo Ideapad P580',
#  'Lenovo 15Iil05',
#  '15-Da0041Dx',
#  'Acer Travelmate-P 645-M',
#  'I5-4300Y',
#  'Lenovo Thinkpad T490S',
#  'Lenovo Thinkpad T420',
#  '14-Ca061Dx',
#  'Hp 840 G1',
#  'Dell Latitude 3350',
#  'Samsung Galaxy Chromebook Go',
#  'Toshiba Tecra',
#  'Dell Inspiron 17 3793',
#  'Lenovo Thinkpad X1 Tablet Gen 3',
#  'Hp Probook 4540S',
#  '7480',
#  'Dell Latitude 5520',
#  'Hp Pavilion 15',
#  'Acer Nitro 5',
#  'Envy 17 17T',
#  'Chromebook',
#  'Lenovo Thinkpad X1 Yoga',
#  'Dell Latitude 7420',
#  'Hp Elitebook Folio 9470M',
#  'Thinkpad T14S Gen 1',
#  'Hp Probook 450 G3',
#  'Latitude 7420',
#  '2',
#  'Gateway Gwnr71517-Bl',
#  'Acer Chromebook',
#  'Precision 7740',
#  'Samsung 700T',
#  'Thinkpad E485',
#  'Elitebook 820 G3 Windows 7',
#  'Samsung Galaxy Book',
#  'Dell Chromebook 11 3120',
#  'Hp 17-Cn3097Nr',
#  'Lenovo N23 Chromebook',
#  'E5530',
#  'Hp Probook 4430S',
#  'Lenovo Thinkpad 13 Chromebook',
#  'Lenovo Flex 3',
#  'Lenovo Thinkpad T540P',
#  'Dell Inspiron 15 3520',
#  'Asus Vivobook Flip',
#  'Dell Latitude 5175',
#  'Dell Latitude 5440',
#  'Dell Precision 7710',
#  'Hp Zbook 14U G5',
#  'Latitude 14 Rugged Extreme 7404',
#  'Thinkpad',
#  'Dell Latitude 5400',
#  'E7470',
#  'Lenovo Thinkpad W530',
#  'Lenovo Thinkpad P51',
#  'Hp Elitebook 840 G8',
#  'Hp Pavilion X360 14-Dw1013Dx',
#  'Dell Precision 5530',
#  'Fujitsu Quaderno A4 (2Nd Gen.)',
#  'Hp Chromebook 11 G4',
#  '47X83Ua#Aba',
#  'Dell Inspiron 15 3000',
#  'Hp Elitebook 8560P']

# %%
ebay_df['Type'] = ebay_df['Type'].str.title()
ebay_df['Type'] = ebay_df['Type'].replace(to_replace=['Netbook', 'Nb'], value='Notebook')
ebay_df['Type'] = ebay_df['Type'].replace(to_replace=['Laptop/Notebook', 'N/A, Notebook/Laptop'], value='Notebook/Laptop')
ebay_df['Type'] = ebay_df['Type'].replace(to_replace=['Laptops', 'Windows Laptop'], value='Laptop')
ebay_df['Type'] = ebay_df['Type'].replace(to_replace=['Tablet/Laptop Convertible', 'Convertible 2-In-1 Laptop/Tablet', 'Touchscreen Laptop', '2 In 1 Laptop/Tablet'], 
                                          value='Laptop/Tablet')
ebay_df['Type'] = ebay_df['Type'].replace(to_replace=['Tablet Computer', 'Rugged Tablet', 'Rugged Tough Tablet'], value='Tablet')
ebay_df['Type'] = ebay_df['Type'].replace(to_replace=['Ultra Rugged Toughbook', 'Getac'], value='Toughbook')

ebay_df = ebay_df[ebay_df['Type'] != 'Cardbus Adapter']
ebay_df = ebay_df[ebay_df['Type'] != 'Lcd Display']

ebay_df['Type'].fillna(value='Laptop', inplace=True)

ebay_df['Type'].unique()
# Out:
# C:\Users\trush\AppData\Local\Temp\ipykernel_33596\362714154.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ebay_df['Type'].fillna(value='Laptop', inplace=True)
# array(['Notebook/Laptop', 'Laptop', 'Notebook', 'Laptop/Tablet',
#        'Chromebook', 'Ultra-Mobile Pc (Umpc)', 'Gaming Laptop Computers',
#        'Toughbook', 'Tablet', 'Ultrabook', 'Panel Pc', 'Convertible',
#        'Notebook/Laptop/Tablet', 'Ebook Reader',
#        'Subnotebook/Ultraportable', '2-In-1 Convertible', 'Computers',
#        'Workstation/Laptop', 'Thinkpad'], dtype=object)

# %%
ebay_df.isna().sum() / len(ebay_df) * 100
# Out:
# Item Number                       0.000000
# Brand                             0.000000
# Processor                         0.914634
# Screen Size (in)                  0.000000
# Color                            38.292683
# Ram Size                         28.963415
# SSD Capacity                     12.865854
# GPU                              31.890244
# Processor Speed                  16.219512
# Type                              0.000000
# Release Year                     74.024390
# Maximum Resolution               24.146341
# Model                             0.000000
# OS                                5.975610
# Hard Drive Capacity              29.329268
# Storage Type                     22.073171
# Condition                        12.195122
# Country Region Of Manufacture     0.000000
# dtype: float64

# %%
ebay_df['Processor'].unique()
# Out:
# array(['Quad Core', 'Intel Core i7 8th Gen.', 'Intel Core i5-6300U',
#        'Intel Celeron N', 'Intel Core i5 6th Gen.', 'Intel Celeron',
#        'Intel Celeron Dual-Core', 'i7 7th', 'Intel Core i3 10th Gen.',
#        '8350U,  Core i5', 'Intel Celeron Processor N4100',
#        'Intel Core i5-8259U', 'Intel Core i5 7th Gen.',
#        'Intel Core i5 8th Gen.', 'Intel Core i7 13th Gen.', 'AMD Ryzen 5',
#        'i5-8365U', 'Intel Core i5 4th Gen.', 'Intel Core i5-1135G7',
#        'Intel Celeron N3160', 'i5-7200U', 'Intel Celeron N4100',
#        'Intel Core i7 12th Gen.', 'Intel Core i5-4300U', 'i7-7820HQ',
#        'Intel Core i5-4200U', 'Intel Celeron N5100',
#        'Intel Core i5-8250U', 'Intel Core i7 13th Gen',
#        'Intel Core i3 6th Gen.', 'Intel i5', 'Intel Core i5',
#        'AMD A4 Dual-Core', 'Intel Core i7 6th Gen.',
#        'Intel Core i5 2nd Gen.', 'NVIDIA Tegra 3', 'i5-7300HQ', 'Core i7',
#        'Intel Core i3-6100U', 'Intel i7-Q740 1.73GHz', 'Intel Core i7',
#        'Intel Core i5-3320M', 'Intel Core i5 11th Gen.',
#        'MediaTek MT8183', 'Intel Core i5 13th Gen.',
#        'Intel Core i5 10th Gen.', 'Intel Core i5 6th Gen',
#        'Intel Core i5-8265U', 'Intel Core i3 11th Gen.',
#        'Intel Core i5-10310u', 'Intel Core i7 4th Gen.', 'unknown',
#        'AMD Ryzen 3Pro', 'Celeron N2930', 'Intel Core i7 7th Gen.',
#        'Intel Core 2 Duo', '8250U', 'Intel Core i3 12th Gen.',
#        'Intel Core i5 4th generation', 'ntel,',
#        'Intel Core i5 6th generation', 'Intel Core M-5Y71', nan, 'Intel',
#        'Intel Core i5 3rd generation', 'Intel Core i3 4th generation',
#        'Intel Core I5-2520M', 'Intel Core i3 7th generation',
#        'Intel Core i3 6th generation', 'Intel Core i5 5th generation',
#        '12th Gen Intel Core i5-12450H', 'Intel Core i7 11th Gen.',
#        '8265U', 'Intel Core i5 7th generation',
#        'Intel Core I5 \u200b\u200b12th Generation',
#        'AMD Ryzen 5 7000 Series', 'i5', 'Intel Core i7 9th Gen.',
#        'AMD Ryzen 7', 'Intel Core i5 9th Gen.', 'Intel Core i5-5300U',
#        'Intel Pentium', 'intel Core m5', 'Intel Core i5 2nd generation',
#        'Intel Core i7 7th Gen', 'Core i5 5300U 2.30 GHz',
#        'Intel Core i3 8th generation', 'Does not apply',
#        'Intel Core i7 10th Gen.', 'i9-13900HX', 'Intel Core i9 13th Gen.',
#        'Intel Xeon', 'Intel Core I5-7200U', 'Intel Core i7 2nd Gen.',
#        'Intel Core i5 3rd Gen.', 'Intel Core i5 12th Gen.',
#        'Intel Core i5-8365U', 'Unknown', 'Intel Core i5 5th Gen.',
#        'Intel Core i7 8th generation', 'I5',
#        'Intel Core i3 10th generation', 'Intel Core i7 6th generation',
#        'Intel Core i5 4th Gen', 'Core i5 6300U 2.40GHz',
#        'Intel Core i5-6300U (6th Gen)', 'Intel Core i3 4th Gen.',
#        'Intel Pentium Gold processor 4415Y', 'i5-4200m', 'i5-6300u',
#        'Intel Core i7-8665U', 'Intel Core i3 2nd Gen.',
#        'Intel Celeron N3350', 'AMD A6 Dual-Core', 'AMD',
#        'INTEL CORE i7 6th gen', 'No', 'Intel Core i7-8550U',
#        'Intel Core i3 3rd Gen.', 'Intel Atom Quad-Core', 'AMD A4-9120C',
#        'Google Tensor G2', 'Amd A4-9120c Radeon R4 Dual-Core',
#        'AMD Ryzen 3 4000 Series', 'Intel Core i5-4300Y',
#        'Intel Core i5 1st Gen.', 'AMD Ryzen 3', 'Intel Core i7-1065G7',
#        'Microsoft SQ2', 'Intel® Core™ i5 i5-3210M',
#        'Intel® Core™ i5 i5-2520M', 'Samsung Exynos 5 Dual',
#        'Intel I7-10610u', 'Intel Core m3 7th Gen.', 'Intel i5-2467M',
#        'core i5 8th gen', 'AMD A4', 'AMD Athlon', 'Intel Core M5',
#        'Unspecified', 'Intel Core i5-7300U 7th Gen.',
#        'AMD Ryzen 7 Pro 3700U', 'i5-8350U',
#        'Intel Core i7-6600U @ 2.6GHz', 'Intel Core i7 3rd Gen.',
#        'Intel Core i5 vPro 8th Gen', 'Intel Core m5 6th Gen.',
#        'Intel Core i3 8th Gen.', 'Intel Core i3-1115G4',
#        'AMD Ryzen 7 7840HS', 'Intel i7-1265U', 'Intel Core i7 8th Gen',
#        'Qualcomm Snapdragon 7c Gen 2', 'Intel Quad i7-6920HQ @2.90GHz',
#        'Intel Core i5-8350U', 'intel N100', 'i5-11500H',
#        'Qualcomm Snapdragon 8cx Gen 2', 'Mediatek',
#        'AMD Ryzen 7 7000 Series', 'Intel Atom Dual-Core',
#        'Intel Pentium Silver N6000', 'Intel Core i3 7th Gen.',
#        'Intel Celeron N2840', 'Intel Core 2 Quad', 'Intel Core i7-13700H',
#        'Intel Pentium Gold', 'Intel Celeron N4020', 'MediaTek MT8173C',
#        'i5 3rd Gen', 'i5-10210U', '10th Gen Intel Core i5',
#        'Intel Core i7-1185G7', 'Arm Cortex-A Series', 'INTEL I5 2nd GEN.',
#        'Intel Celeron N3050', 'Intel Pentium M', 'Intel Celeron N4500',
#        'Intel Core i7-1355U', 'Android 4.0',
#        '11th Gen Intel Core i5-1135G7', 'Intel Core i7 1st Gen.',
#        '11 Gen intel Core i3', 'E3-1505M v6', 'Intel® Core™ i7 i7-6500U',
#        'FZ-G1', 'Intel i7-8665U QuadCore 8th Gen', 'AMD Ryzen 5 5500U',
#        'Radeon R4 Dual-Core', 'INTEL Core i7-7Y75', 'Intel Pentium N4200',
#        'Intel Pentium N Quad Core', 'MediaTek', 'Intel Celeron N4000',
#        'Intel Core i5-7300U', 'INTEL CORE i5', 'Intel Pentium III',
#        'i5-8350', 'AMD Turion II', 'Mediatek M8173c',
#        'Intel Celeron 4100', 'Intel Pentium Gold 8505',
#        'AMD Athlon Gold 3150U',
#        '12th Gen Intel® Core™ i5-12450H Processor', '1660Ti',
#        'Qualcomm Kryo 468', 'Intel Core i7-6600U', 'AMD Ryzen 3 Pro',
#        'Intel Celeron N2940 1.83GHz Quad', 'Intel Core I5-8300H',
#        'Intel Core i3', 'Intel Core i5-6200U', 'MediaTek 820 (8192)',
#        'i7-1165G7', 'Core i5-10210U', 'Intel Corei7-8850H',
#        'intel core i5 8th gen', 'AMD Ryzen 7 PRO 4750U',
#        'NVIDIA Tegra K1', 'Intel Core i7-5600U', 'Intel core i7 4th gen',
#        'Intel Core i7 3rd gen,  4 cores,  8 logical processors',
#        'Intel Core i5 5300U', 'Dual Core', 'Intel i5 6th Gen.',
#        'AMD Ryzen 9', 'Intel Core i5 6300U', 'intel i5',
#        'AMD A6-7310 APU', 'Intel Core i7 5th Gen.', 'Intel i7 2nd Gen.',
#        'Quad-Core Intel N100', 'Intel Inside',
#        'Intel Core i5 4th Gen. 2.70GHz', 'i7-6600U', 'Intel Core I-5',
#        'AMD A6-9220C', 'AMD Radeon R4', 'Intel Core i3 5th Gen.',
#        'intel core i7', 'core i5', 'Intel Core', 'Intel Core i5 1st gen.',
#        'Intel Core I7-7700HQ CPU', 'AMD A9', 'Intel i3-5020u', 'i5 L16G7',
#        '6300U, Core i5', 'AMD Ryzen 5 3rd Gen.',
#        'Intel Celeron N3050 1.6GHz Dual-Core',
#        '13th Gen Intel® Core™ i5-13420H Processor',
#        'Intel Core i7 i7-1355U', 'AMD A6 Quad-Core',
#        'Intel Celeron N3060', 'intel core i3', 'AMD Ryzen 7 PRO 6850U',
#        'INTEL CELERON N2840', 'intel core i5 6th gen',
#        'AMD Ryzen 7 Quad-Core', 'Intel i5-2520m',
#        'Arm Rockchip Rk3288 Cortex A17 Quad-CORE', 'AMD A8 Quad-Core',
#        'Intel Core i7-4700 @ 2.4 GHz', 'i7-6500U', 'Intel Celeron M',
#        'intel Atom x5 z8350', 'Intel Core i5 7th Gen',
#        'Intel Core i7 Extreme 4th Gen.', '6300U',
#        'Intel Core 2 Duo, Intel Core 2 Duo T7100 (1.8GHz)',
#        'Qualcomm® Snapdragon™ 8cx Gen 2', 'Intel Core i5 Mobile',
#        'Intel A100', 'Intel Pentium Silver', 'AMD E-Series',
#        'Intel Core i3-1220P', 'AMD Turion 64', 'Intel Core i5-10310U',
#        'Intel Core i7 7th generation', 'AMD A10', 'I5-10210U',
#        'A10-8730B', 'Intel Pentium N-Series', 'Intel® Core™ i5 i5-5200U',
#        'Qualcomm Snapdragon 7c', 'Intel Core Duo T2300',
#        'Intel Core i7-6820HQ',
#        '13th Gen Intel® Core™ i9-13900H Processor', 'Intel Core i3-1215U',
#        'intel core i7 6th gen', 'Amd 7th generation',
#        'Intel i5-7200U @2.50 GHz,  2701 Mhz,  2Core(s)',
#        'Intel Core i5-3210M'], dtype=object)
